# %%
import pandas as pd
import numpy as np

dfs = []
for i in range(2017,2022):
    df = pd.read_csv(f"./{i}_lake_data.csv")
    df["Year"] = i  # Fill the Year column with the current year
    dfs.append(df)

df = pd.concat(dfs)
df
# Out:
#      STN Code                        Name of Monitoring Location  \
# 0      1790.0                    PULICATE LAKE , NELLORE \nDIST.
# 1      2353.0  KONDACHARLA-AAVA LAKE, \nPARAWADA PHARMA CITY,...
# 2      2205.0                     MER BEEL AT MADHABPUR, \nASSAM
# 3      2206.0                DALONI BEEL NEAR \nJOGIGHOPA, ASSAM
# 4      1263.0  ELANGABEEL SYSTEM POND \n(CONNECTED TO R. KOLA...
# ..        ...                                                ...
# 615    1765.0  RABINDRASAROVAR NATIONAL LAKE, \nCALCUTTA, WES...
# 616    2544.0                              SAHEBBANDH AT PURULIA
# 617    2522.0                        SINCHAL LAKE FOR DARJEELING
# 618    2521.0         WATER RESERVIOR AT DELO LAKE, \nDARJELLING
# 619    4725.0                  WATER RESERVIOR ST. HELENS SCHOOL
#
#     Type Water Body        State Name Min Temperature Max Temperature  \
# 0              LAKE  ANDHRA \nPRADESH            27.0            28.0
# 1              LAKE  ANDHRA \nPRADESH            24.0            28.0
# 2              LAKE             ASSAM            20.0            27.0
# 3              LAKE             ASSAM            22.0            36.0
# 4              POND             ASSAM            22.0            34.0
# ..              ...               ...             ...             ...
# 615            LAKE       WEST BENGAL            22.0            31.0
# 616            LAKE       WEST BENGAL            22.0            32.0
# 617            LAKE       WEST BENGAL             7.0            16.0
# 618            LAKE       WEST BENGAL             9.0            24.0
# 619            LAKE       WEST BENGAL             8.0            18.0
#
#     Min Dissolved Oxygen Max Dissolved Oxygen Min pH Max pH  ...  \
# 0                    5.1                  6.9    7.1    8.5  ...
# 1                    5.9                  6.8    6.9    8.4  ...
# 2                    2.2                  7.2    5.7    7.0  ...
# 3                    5.1                  6.0    6.6    7.8  ...
# 4                    0.7                  4.6    6.8    8.4  ...
# ..                   ...                  ...    ...    ...  ...
# 615                  5.2                  9.7    7.2    8.5  ...
# 616                  8.8                  9.8    7.0    7.6  ...
# 617                  7.1                  8.1    6.9    7.6  ...
# 618                  7.2                  8.2    6.9    7.6  ...
# 619                  7.1                  8.5    6.9    7.9  ...
#
#     Max Conductivity Min BOD Max BOD Min Nitrate N + Nitrite N  \
# 0           156600.0     1.0     2.3                      0.65
# 1             1034.0     1.3     2.3                      1.16
# 2              128.0     1.0    16.2                       0.1
# 3              153.0     0.9     2.8                       0.1
# 4              972.0     4.5    14.7                       0.8
# ..               ...     ...     ...                       ...
# 615              826     1.8     4.1                      0.30
# 616              422     2.7     7.3                      0.30
# 617               29     1.0     1.1                      0.30
# 618               36     1.0     1.8                      0.30
# 619               73     1.0     1.6                      0.30
#
#     Max Nitrate N + Nitrite N Min Fecal Coliform Max Fecal Coliform  \
# 0                         6.9                2.0                2.0
# 1                        3.36               11.0               29.0
# 2                         1.7              300.0             2000.0
# 3                         1.4              300.0             1200.0
# 4                         5.7             1100.0             3500.0
# ..                        ...                ...                ...
# 615                      1.90                330                790
# 616                      0.80               3100               9400
# 617                      0.30                 70                110
# 618                      0.30                 60                130
# 619                      0.30                 70                110
#
#     Min Total Coliform Max Total Coliform  Year
# 0                800.0             1600.0  2017
# 1                350.0             2400.0  2017
# 2                360.0             6400.0  2017
# 3                300.0             5300.0  2017
# 4                730.0            21000.0  2017
# ..                 ...                ...   ...
# 615               1100               1700  2021
# 616               4300              12000  2021
# 617                110                210  2021
# 618                110                330  2021
# 619                110                330  2021
#
# [2547 rows x 21 columns]

# %%
#using only data of lakes
df = df[df["Type Water Body"]=="LAKE"]

#drop rows containing blank values
df = df.dropna()

#some entries in the pdf have - to represent a blank value so we must remove those as well
bad_vals = df.apply(lambda x:x=="-").any(axis=1)
bad_idx = bad_vals.index[bad_vals]
df = df.drop(bad_idx)

#replace below detection level with 0
df = df.replace("BDL",0)

df.reset_index(inplace=True,drop=True)
df
# Out:
#       STN Code                        Name of Monitoring Location  \
# 0       1790.0                    PULICATE LAKE , NELLORE \nDIST.
# 1       2353.0  KONDACHARLA-AAVA LAKE, \nPARAWADA PHARMA CITY,...
# 2       2205.0                     MER BEEL AT MADHABPUR, \nASSAM
# 3       2206.0                DALONI BEEL NEAR \nJOGIGHOPA, ASSAM
# 4       2557.0                     KAWAR LAKE, BEGUSARAI, \nBIHAR
# ...        ...                                                ...
# 1088    1765.0  RABINDRASAROVAR NATIONAL LAKE, \nCALCUTTA, WES...
# 1089    2544.0                              SAHEBBANDH AT PURULIA
# 1090    2522.0                        SINCHAL LAKE FOR DARJEELING
# 1091    2521.0         WATER RESERVIOR AT DELO LAKE, \nDARJELLING
# 1092    4725.0                  WATER RESERVIOR ST. HELENS SCHOOL
#
#      Type Water Body        State Name Min Temperature Max Temperature  \
# 0               LAKE  ANDHRA \nPRADESH            27.0            28.0
# 1               LAKE  ANDHRA \nPRADESH            24.0            28.0
# 2               LAKE             ASSAM            20.0            27.0
# 3               LAKE             ASSAM            22.0            36.0
# 4               LAKE             BIHAR            19.0            32.0
# ...              ...               ...             ...             ...
# 1088            LAKE       WEST BENGAL            22.0            31.0
# 1089            LAKE       WEST BENGAL            22.0            32.0
# 1090            LAKE       WEST BENGAL             7.0            16.0
# 1091            LAKE       WEST BENGAL             9.0            24.0
# 1092            LAKE       WEST BENGAL             8.0            18.0
#
#      Min Dissolved Oxygen Max Dissolved Oxygen Min pH Max pH  ...  \
# 0                     5.1                  6.9    7.1    8.5  ...
# 1                     5.9                  6.8    6.9    8.4  ...
# 2                     2.2                  7.2    5.7    7.0  ...
# 3                     5.1                  6.0    6.6    7.8  ...
# 4                     5.4                  8.0    7.2    7.9  ...
# ...                   ...                  ...    ...    ...  ...
# 1088                  5.2                  9.7    7.2    8.5  ...
# 1089                  8.8                  9.8    7.0    7.6  ...
# 1090                  7.1                  8.1    6.9    7.6  ...
# 1091                  7.2                  8.2    6.9    7.6  ...
# 1092                  7.1                  8.5    6.9    7.9  ...
#
#      Max Conductivity Min BOD Max BOD Min Nitrate N + Nitrite N  \
# 0            156600.0     1.0     2.3                      0.65
# 1              1034.0     1.3     2.3                      1.16
# 2               128.0     1.0    16.2                       0.1
# 3               153.0     0.9     2.8                       0.1
# 4               325.0     2.1     2.8                       0.0
# ...               ...     ...     ...                       ...
# 1088              826     1.8     4.1                      0.30
# 1089              422     2.7     7.3                      0.30
# 1090               29     1.0     1.1                      0.30
# 1091               36     1.0     1.8                      0.30
# 1092               73     1.0     1.6                      0.30
#
#      Max Nitrate N + Nitrite N Min Fecal Coliform Max Fecal Coliform  \
# 0                          6.9                2.0                2.0
# 1                         3.36               11.0               29.0
# 2                          1.7              300.0             2000.0
# 3                          1.4              300.0             1200.0
# 4                          0.0             7000.0            26000.0
# ...                        ...                ...                ...
# 1088                      1.90                330                790
# 1089                      0.80               3100               9400
# 1090                      0.30                 70                110
# 1091                      0.30                 60                130
# 1092                      0.30                 70                110
#
#      Min Total Coliform Max Total Coliform  Year
# 0                 800.0             1600.0  2017
# 1                 350.0             2400.0  2017
# 2                 360.0             6400.0  2017
# 3                 300.0             5300.0  2017
# 4               15000.0            38000.0  2017
# ...                 ...                ...   ...
# 1088               1100               1700  2021
# 1089               4300              12000  2021
# 1090                110                210  2021
# 1091                110                330  2021
# 1092                110                330  2021
#
# [1093 rows x 21 columns]

# %%
#Required Columns
L = [
  "Min Temperature","Max Temperature","Min Dissolved Oxygen","Max Dissolved Oxygen",
  "Min pH","Max pH","Min Conductivity","Max Conductivity","Min BOD","Max BOD",
  "Min Nitrate N + Nitrite N","Max Nitrate N + Nitrite N","Min Fecal Coliform",
  "Max Fecal Coliform","Min Total Coliform","Max Total Coliform", "Year"
]
df[L] = df[L].apply(pd.to_numeric)

#dropping redundant columns
# df = df.drop(columns=["Name of Monitoring Location","Type Water Body"])
df = df.drop(columns=["Type Water Body"])
df = df.astype({"STN Code":int})
df
# Out:
#       STN Code                        Name of Monitoring Location  \
# 0         1790                    PULICATE LAKE , NELLORE \nDIST.
# 1         2353  KONDACHARLA-AAVA LAKE, \nPARAWADA PHARMA CITY,...
# 2         2205                     MER BEEL AT MADHABPUR, \nASSAM
# 3         2206                DALONI BEEL NEAR \nJOGIGHOPA, ASSAM
# 4         2557                     KAWAR LAKE, BEGUSARAI, \nBIHAR
# ...        ...                                                ...
# 1088      1765  RABINDRASAROVAR NATIONAL LAKE, \nCALCUTTA, WES...
# 1089      2544                              SAHEBBANDH AT PURULIA
# 1090      2522                        SINCHAL LAKE FOR DARJEELING
# 1091      2521         WATER RESERVIOR AT DELO LAKE, \nDARJELLING
# 1092      4725                  WATER RESERVIOR ST. HELENS SCHOOL
#
#             State Name  Min Temperature  Max Temperature  \
# 0     ANDHRA \nPRADESH             27.0             28.0
# 1     ANDHRA \nPRADESH             24.0             28.0
# 2                ASSAM             20.0             27.0
# 3                ASSAM             22.0             36.0
# 4                BIHAR             19.0             32.0
# ...                ...              ...              ...
# 1088       WEST BENGAL             22.0             31.0
# 1089       WEST BENGAL             22.0             32.0
# 1090       WEST BENGAL              7.0             16.0
# 1091       WEST BENGAL              9.0             24.0
# 1092       WEST BENGAL              8.0             18.0
#
#       Min Dissolved Oxygen  Max Dissolved Oxygen  Min pH  Max pH  \
# 0                      5.1                   6.9     7.1     8.5
# 1                      5.9                   6.8     6.9     8.4
# 2                      2.2                   7.2     5.7     7.0
# 3                      5.1                   6.0     6.6     7.8
# 4                      5.4                   8.0     7.2     7.9
# ...                    ...                   ...     ...     ...
# 1088                   5.2                   9.7     7.2     8.5
# 1089                   8.8                   9.8     7.0     7.6
# 1090                   7.1                   8.1     6.9     7.6
# 1091                   7.2                   8.2     6.9     7.6
# 1092                   7.1                   8.5     6.9     7.9
#
#       Min Conductivity  Max Conductivity  Min BOD  Max BOD  \
# 0               3270.0          156600.0      1.0      2.3
# 1                597.0            1034.0      1.3      2.3
# 2                 50.0             128.0      1.0     16.2
# 3                 54.0             153.0      0.9      2.8
# 4                222.0             325.0      2.1      2.8
# ...                ...               ...      ...      ...
# 1088             252.0             826.0      1.8      4.1
# 1089             311.0             422.0      2.7      7.3
# 1090              13.0              29.0      1.0      1.1
# 1091              20.0              36.0      1.0      1.8
# 1092              16.0              73.0      1.0      1.6
#
#       Min Nitrate N + Nitrite N  Max Nitrate N + Nitrite N  \
# 0                          0.65                       6.90
# 1                          1.16                       3.36
# 2                          0.10                       1.70
# 3                          0.10                       1.40
# 4                          0.00                       0.00
# ...                         ...                        ...
# 1088                       0.30                       1.90
# 1089                       0.30                       0.80
# 1090                       0.30                       0.30
# 1091                       0.30                       0.30
# 1092                       0.30                       0.30
#
#       Min Fecal Coliform  Max Fecal Coliform  Min Total Coliform  \
# 0                    2.0                 2.0               800.0
# 1                   11.0                29.0               350.0
# 2                  300.0              2000.0               360.0
# 3                  300.0              1200.0               300.0
# 4                 7000.0             26000.0             15000.0
# ...                  ...                 ...                 ...
# 1088               330.0               790.0              1100.0
# 1089              3100.0              9400.0              4300.0
# 1090                70.0               110.0               110.0
# 1091                60.0               130.0               110.0
# 1092                70.0               110.0               110.0
#
#       Max Total Coliform  Year
# 0                 1600.0  2017
# 1                 2400.0  2017
# 2                 6400.0  2017
# 3                 5300.0  2017
# 4                38000.0  2017
# ...                  ...   ...
# 1088              1700.0  2021
# 1089             12000.0  2021
# 1090               210.0  2021
# 1091               330.0  2021
# 1092               330.0  2021
#
# [1093 rows x 20 columns]

# %%
test = pd.read_csv("2019_lake_data.csv")
test = test.groupby("STN Code").size()
test = test.reset_index(name="Count")
filtered = test[test["Count"] > 1]

print(test)
# Out:
#      STN Code  Count
# 0        1263      1
# 1        1285      1
# 2        1286      1
# 3        1291      1
# 4        1292      1
# ..        ...    ...
# 524      4729      1
# 525      4740      1
# 526      4741      1
# 527      4795      1
# 528      4823      1
#
# [529 rows x 2 columns]

# %%
# Group by 'STN Code' and count the occurrences of each code
stn_counts = df.groupby("STN Code").size()

# Convert to a DataFrame for better readability (optional)
stn_counts = stn_counts.reset_index(name="Count")

print(stn_counts)
# Out:
#      STN Code  Count
# 0        1285      4
# 1        1286      4
# 2        1291      4
# 3        1292      4
# 4        1297      5
# ..        ...    ...
# 334      5059      1
# 335      5060      1
# 336      5061      1
# 337      5062      1
# 338      5063      1
#
# [339 rows x 2 columns]

# %% [markdown]
# # Calculating WQI

# %% [markdown]
# To calculate water quality index, we can use the Weighted Arithmetic Mean method
#
# $$ WQI = \frac{\sum q_iw_i}{\sum w_i} $$
#
# Here, $w_i$ represents unit weight of ith parameter towards overall water quality and $q_i$ is the quality estimate of the ith parameter. They can be calculated as follows
#
# $$ q_i = \frac{V_i - V_{ideal} }{S_i - V_{ideal}} * 100 $$
#
# $$ w_i = \frac{K}{S_i} $$
#
# $K$ is the constant of proportionality and is defined by
#
# $$ K = \frac{1}{\sum S_i} $$ <br />
#
# | Parameter | Standard Value ($S_i$) |
# |:-:|:-:|
# | Dissolved Oxygen (mg/L) | 10 |
# | pH | 8.5 |
# | Conductivity (µS/cm) | 1000 |
# | Biological Oxygen Demand (mg/L) | 5 |
# | Nitrate (mg/L) | 45 |
# | Fecal Coliform (per 100 mL) | 100 |
# | Total Coliform (per 100 mL) | 1000 |

# %%
stv = np.array([10,8.5,1000,5,45,100,1000])
K = 1/np.sum(stv)
w = [K/x for x in stv]
w_n = np.array([x/sum(w) for x in w])
print(w_n)
# Out:
# [0.22130294 0.2603564  0.00221303 0.44260588 0.04917843 0.02213029
#  0.00221303]

# %%
idv = np.array([14.6,7,0,0,0,0,0])
diff = stv-idv

def calculate_wqi(row):
    q = 100*(row - idv)/diff
    return np.dot(q,w_n)

example_row = np.array([6.8,7.8,1179,4.6,3.56,23,240])
calculate_wqi(example_row)
# Out:
# np.float64(93.34277805867758)

# %%
def avg(col1,col2):
    return (col1.to_numpy() + col2.to_numpy())/2

pd.set_option('mode.chained_assignment',None)

df_a = pd.DataFrame()
df_a["Dissolved Oxygen"] = avg(df["Min Dissolved Oxygen"],df["Max Dissolved Oxygen"])
df_a["Location Name"] = df["Name of Monitoring Location"].apply(lambda x: x.split(",")[0].strip().replace('\n', ''))
df_a["Year"] = df ["Year"]
df_a["pH"] = avg(df["Min pH"],df["Max pH"])
df_a["Conductivity"] = avg(df["Min Conductivity"],df["Max Conductivity"])
df_a["BOD"] = avg(df["Min BOD"],df["Max BOD"])
df_a["Nitrate N + Nitrite N"] = avg(df["Min Nitrate N + Nitrite N"],df["Max Nitrate N + Nitrite N"])
df_a["Fecal Coliform"] = avg(df["Min Fecal Coliform"],df["Max Fecal Coliform"])
df_a["Total Coliform"] = avg(df["Min Total Coliform"],df["Max Total Coliform"])
df_a
# Out:
#       Dissolved Oxygen                      Location Name  Year    pH  \
# 0                 6.00                      PULICATE LAKE  2017  7.80
# 1                 6.35              KONDACHARLA-AAVA LAKE  2017  7.65
# 2                 4.70              MER BEEL AT MADHABPUR  2017  6.35
# 3                 5.55         DALONI BEEL NEAR JOGIGHOPA  2017  7.20
# 4                 6.70                         KAWAR LAKE  2017  7.55
# ...                ...                                ...   ...   ...
# 1088              7.45      RABINDRASAROVAR NATIONAL LAKE  2021  7.85
# 1089              9.30              SAHEBBANDH AT PURULIA  2021  7.30
# 1090              7.60        SINCHAL LAKE FOR DARJEELING  2021  7.25
# 1091              7.70       WATER RESERVIOR AT DELO LAKE  2021  7.25
# 1092              7.80  WATER RESERVIOR ST. HELENS SCHOOL  2021  7.40
#
#       Conductivity   BOD  Nitrate N + Nitrite N  Fecal Coliform  \
# 0          79935.0  1.65                  3.775             2.0
# 1            815.5  1.80                  2.260            20.0
# 2             89.0  8.60                  0.900          1150.0
# 3            103.5  1.85                  0.750           750.0
# 4            273.5  2.45                  0.000         16500.0
# ...            ...   ...                    ...             ...
# 1088         539.0  2.95                  1.100           560.0
# 1089         366.5  5.00                  0.550          6250.0
# 1090          21.0  1.05                  0.300            90.0
# 1091          28.0  1.40                  0.300            95.0
# 1092          44.5  1.30                  0.300            90.0
#
#       Total Coliform
# 0             1200.0
# 1             1375.0
# 2             3380.0
# 3             2800.0
# 4            26500.0
# ...              ...
# 1088          1400.0
# 1089          8150.0
# 1090           160.0
# 1091           220.0
# 1092           220.0
#
# [1093 rows x 9 columns]

# %%
wqi = df_a.drop(columns=['Location Name', 'Year']).apply(calculate_wqi,axis=1)
df_a["WQI"] = wqi
df_a = df_a[df_a["WQI"]>=0]
df_a.dropna()
df_a.insert(0,"STN Code",df["STN Code"])
df_a
# df_a["Name of Monitoring Location"] = df_a["Name of Monitoring Location"].str.replace("\n", "")
# # Export the DataFrame to a CSV file
# df_a.to_csv("updated_locations.csv", index=False)

# print("DataFrame exported to 'updated_locations.csv'")
# Out:
#       STN Code  Dissolved Oxygen                      Location Name  Year  \
# 0         1790              6.00                      PULICATE LAKE  2017
# 1         2353              6.35              KONDACHARLA-AAVA LAKE  2017
# 2         2205              4.70              MER BEEL AT MADHABPUR  2017
# 3         2206              5.55         DALONI BEEL NEAR JOGIGHOPA  2017
# 4         2557              6.70                         KAWAR LAKE  2017
# ...        ...               ...                                ...   ...
# 1088      1765              7.45      RABINDRASAROVAR NATIONAL LAKE  2021
# 1089      2544              9.30              SAHEBBANDH AT PURULIA  2021
# 1090      2522              7.60        SINCHAL LAKE FOR DARJEELING  2021
# 1091      2521              7.70       WATER RESERVIOR AT DELO LAKE  2021
# 1092      4725              7.80  WATER RESERVIOR ST. HELENS SCHOOL  2021
#
#         pH  Conductivity   BOD  Nitrate N + Nitrite N  Fecal Coliform  \
# 0     7.80       79935.0  1.65                  3.775             2.0
# 1     7.65         815.5  1.80                  2.260            20.0
# 2     6.35          89.0  8.60                  0.900          1150.0
# 3     7.20         103.5  1.85                  0.750           750.0
# 4     7.55         273.5  2.45                  0.000         16500.0
# ...    ...           ...   ...                    ...             ...
# 1088  7.85         539.0  2.95                  1.100           560.0
# 1089  7.30         366.5  5.00                  0.550          6250.0
# 1090  7.25          21.0  1.05                  0.300            90.0
# 1091  7.25          28.0  1.40                  0.300            95.0
# 1092  7.40          44.5  1.30                  0.300            90.0
#
#       Total Coliform         WQI
# 0             1200.0   88.277923
# 1             1375.0   68.080478
# 2             3380.0  138.790236
# 3             2800.0   80.709022
# 4            26500.0  440.315367
# ...              ...         ...
# 1088          1400.0   88.207735
# 1089          8150.0  215.224834
# 1090           160.0   49.375099
# 1091           220.0   52.117725
# 1092           220.0   53.247984
#
# [1090 rows x 11 columns]

# %%
df_loc = pd.read_csv("updated_locations.csv")

filtered_data = df_loc[['STN Code', 'lat', 'lon']].copy()
distinct_data = filtered_data.drop_duplicates(subset='STN Code')
# Save the resulting DataFrame to a new CSV (optional)
output_file = 'filtered_data.csv'  # Replace with your desired output file name
distinct_data.to_csv(output_file, index=False)

# Print the resulting DataFrame
print(distinct_data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df_loc = pd.read_csv("updated_locations.csv")
#       3 filtered_data = df_loc[['STN Code', 'lat', 'lon']].copy()
#       4 distinct_data = filtered_data.drop_duplicates(subset='STN Code')
#
# File c:\anaconda\envs\MLOPs\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\anaconda\envs\MLOPs\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\anaconda\envs\MLOPs\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\anaconda\envs\MLOPs\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\anaconda\envs\MLOPs\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'updated_locations.csv'

# %%
# Perform a left merge to add 'lat' and 'lon' to df_a based on 'STN Code'
df_a = df_a.merge(distinct_data, on='STN Code', how='left')

# Print the updated DataFrame
print(df_a)

# Save the updated DataFrame to a new CSV (optional)
updated_file = 'updated_df_a.csv'
df_a.to_csv(updated_file, index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Perform a left merge to add 'lat' and 'lon' to df_a based on 'STN Code'
# ----> 2 df_a = df_a.merge(distinct_data, on='STN Code', how='left')
#       4 # Print the updated DataFrame
#       5 print(df_a)
#
# NameError: name 'distinct_data' is not defined

# %%
import pandas as pd
df = pd.read_csv("water_quality_index.csv")
df["STN Code"].nunique()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("water_quality_index.csv")
#       3 df["STN Code"].nunique()
#
# File c:\anaconda\envs\MLOPs\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\anaconda\envs\MLOPs\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\anaconda\envs\MLOPs\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\anaconda\envs\MLOPs\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\anaconda\envs\MLOPs\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'water_quality_index.csv'

# %%
counts = [0]*5
counts[0] = len(df_a[df_a["WQI"]<50])
counts[1] = len(df_a[(df_a["WQI"]>=50) & (df_a["WQI"]<100)])
counts[2] = len(df_a[(df_a["WQI"]>=100) & (df_a["WQI"]<200)])
counts[3] = len(df_a[(df_a["WQI"]>=200) & (df_a["WQI"]<300)])
counts[4] = len(df_a[df_a["WQI"]>=300])
print(counts)
# Out:
# [31, 461, 248, 102, 248]

# %%
df_a = df_a[df_a["WQI"]<2000]
df_a
# Out:
#       STN Code  Dissolved Oxygen                      Location Name  Year  \
# 0         1790              6.00                      PULICATE LAKE  2017
# 1         2353              6.35              KONDACHARLA-AAVA LAKE  2017
# 2         2205              4.70              MER BEEL AT MADHABPUR  2017
# 3         2206              5.55         DALONI BEEL NEAR JOGIGHOPA  2017
# 4         2557              6.70                         KAWAR LAKE  2017
# ...        ...               ...                                ...   ...
# 1085      1765              7.45      RABINDRASAROVAR NATIONAL LAKE  2021
# 1086      2544              9.30              SAHEBBANDH AT PURULIA  2021
# 1087      2522              7.60        SINCHAL LAKE FOR DARJEELING  2021
# 1088      2521              7.70       WATER RESERVIOR AT DELO LAKE  2021
# 1089      4725              7.80  WATER RESERVIOR ST. HELENS SCHOOL  2021
#
#         pH  Conductivity   BOD  Nitrate N + Nitrite N  Fecal Coliform  \
# 0     7.80       79935.0  1.65                  3.775             2.0
# 1     7.65         815.5  1.80                  2.260            20.0
# 2     6.35          89.0  8.60                  0.900          1150.0
# 3     7.20         103.5  1.85                  0.750           750.0
# 4     7.55         273.5  2.45                  0.000         16500.0
# ...    ...           ...   ...                    ...             ...
# 1085  7.85         539.0  2.95                  1.100           560.0
# 1086  7.30         366.5  5.00                  0.550          6250.0
# 1087  7.25          21.0  1.05                  0.300            90.0
# 1088  7.25          28.0  1.40                  0.300            95.0
# 1089  7.40          44.5  1.30                  0.300            90.0
#
#       Total Coliform         WQI        lat        lon
# 0             1200.0   88.277923  13.695333  80.059293
# 1             1375.0   68.080478  17.603203  83.000845
# 2             3380.0  138.790236  26.407384  93.255130
# 3             2800.0   80.709022  26.407384  93.255130
# 4            26500.0  440.315367  25.512541  86.088339
# ...              ...         ...        ...        ...
# 1085          1400.0   88.207735  22.572646  88.363895
# 1086          8150.0  215.224834  22.996495  87.685588
# 1087           160.0   49.375099  22.996495  87.685588
# 1088           220.0   52.117725  22.996495  87.685588
# 1089           220.0   53.247984  22.996495  87.685588
#
# [1007 rows x 13 columns]

# %%
# Supprimer les doublons en fonction de la colonne 'STN Code'
df_unique = df.drop_duplicates(subset=['STN Code'])

# Afficher le DataFrame sans doublons
df_unique
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Supprimer les doublons en fonction de la colonne 'STN Code'
# ----> 2 df_unique = df.drop_duplicates(subset=['STN Code'])
#       4 # Afficher le DataFrame sans doublons
#       5 df_unique
#
# NameError: name 'df' is not defined
